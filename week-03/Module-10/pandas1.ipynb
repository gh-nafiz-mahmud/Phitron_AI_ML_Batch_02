# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\nafiz-shawon\\.cache\\kagglehub\\datasets\\kundanbedmutha\\student-performance-dataset\\versions\\1\\Student_Performance.csv")
df
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 0               1   14    male      public    post graduate          3.1
# 1               2   18  female      public         graduate          3.7
# 2               3   17  female     private    post graduate          7.9
# 3               4   16   other      public      high school          1.1
# 4               5   16  female      public      high school          1.3
# ...           ...  ...     ...         ...              ...          ...
# 24995       12047   17  female      public              phd          1.8
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# ...

# %%
df.head(5)
# Out:
#    student_id  age  gender school_type parent_education  study_hours  \
# 0           1   14    male      public    post graduate          3.1
# 1           2   18  female      public         graduate          3.7
# 2           3   17  female     private    post graduate          7.9
# 3           4   16   other      public      high school          1.1
# 4           5   16  female      public      high school          1.3
#
#    attendance_percentage internet_access travel_time extra_activities  \
# 0                   84.3             yes     <15 min              yes
# 1                   87.8             yes     >60 min               no
# 2                   65.5              no     <15 min               no
# 3                   58.1              no   15-30 min               no
# 4                   61.0             yes   30-60 min              yes
#
#   study_method  math_score  science_score  english_score  overall_score  \
# ...

# %%
df.tail()
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 24995       12047   17  female      public              phd          1.8
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# 24995                   55.2             yes   15-30 min               no
# 24996                   97.1             yes     <15 min               no
# 24997                   63.0             yes     <15 min               no
# 24998                   69.4             yes   15-30 min              yes
# 24999                   60.3             yes   30-60 min               no
#
#       study_method  math_score  science_score  english_score  overall_score  \
# ...

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'school_type', 'parent_education',
#        'study_hours', 'attendance_percentage', 'internet_access',
#        'travel_time', 'extra_activities', 'study_method', 'math_score',
#        'science_score', 'english_score', 'overall_score', 'final_grade'],
#       dtype='object')

# %%
df_columns = np.array(df.columns) 
df_columns
# Out:
# array(['student_id', 'age', 'gender', 'school_type', 'parent_education',
#        'study_hours', 'attendance_percentage', 'internet_access',
#        'travel_time', 'extra_activities', 'study_method', 'math_score',
#        'science_score', 'english_score', 'overall_score', 'final_grade'],
#       dtype=object)

# %%
print(df_columns.dtype)
# Out:
# object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25000, step=1)

# %%
df.info
# Out:
# <bound method DataFrame.info of        student_id  age  gender school_type parent_education  study_hours  \
# 0               1   14    male      public    post graduate          3.1
# 1               2   18  female      public         graduate          3.7
# 2               3   17  female     private    post graduate          7.9
# 3               4   16   other      public      high school          1.1
# 4               5   16  female      public      high school          1.3
# ...           ...  ...     ...         ...              ...          ...
# 24995       12047   17  female      public              phd          1.8
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
# ...

# %%
df.sample(10)
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 19108        3199   19    male      public        no formal          5.0
# 24950        3383   19    male     private        no formal          2.3
# 13925       13926   17  female      public    post graduate          1.8
# 1779         1780   18  female      public              phd          6.8
# 24003        3202   19    male      public      high school          4.1
# 6345         6346   18    male     private        no formal          2.2
# 17443        8942   19   other      public    post graduate          2.4
# 14201       14202   16   other     private          diploma          2.6
# 18725        4261   15   other      public        no formal          7.2
# 4247         4248   15   other     private         graduate          3.9
#
#        attendance_percentage internet_access travel_time extra_activities  \
# 19108                   82.4             yes   15-30 min              yes
# ...

# %%
df.describe()
# Out:
#         student_id           age   study_hours  attendance_percentage  \
# count  25000.00000  25000.000000  25000.000000           25000.000000
# mean    7493.04380     16.482760      4.253224              75.084084
# std     4323.56215      1.703895      2.167541              14.373171
# min        1.00000     14.000000      0.500000              50.000000
# 25%     3743.75000     15.000000      2.400000              62.800000
# 50%     7461.50000     16.000000      4.300000              75.100000
# 75%    11252.00000     18.000000      6.100000              87.500000
# max    15000.00000     19.000000      8.000000             100.000000
#
#          math_score  science_score  english_score  overall_score
# count  25000.000000   25000.000000   25000.000000   25000.000000
# mean      63.785944      63.745320      63.681948      64.006172
# std       20.875262      20.970529      20.792693      18.932025
# min        0.000000       0.000000       0.000000      14.500000
# ...

# %%
my_list = [['nafiz', 23], ['mahmud', 343], ['shawon', 454]]
list_df = pd.DataFrame(my_list, columns=['name', 'age'], index=[1,2,3])
list_df
# Out:
#      name  age
# 1   nafiz   23
# 2  mahmud  343
# 3  shawon  454

# %%
print(type(list_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
my_tuple = (('nafiz', 23), ('mahmud', 343), ('shawon', 454))
tuple_df = pd.DataFrame(my_tuple, columns=['name', 'age'], index=[1,2,3])
tuple_df
# Out:
#      name  age
# 1   nafiz   23
# 2  mahmud  343
# 3  shawon  454

# %%
my_dict = {
    'Name': ['nafiz', 'mahmud', 'shawon'],
    'Ago': [23,34,45],
    'dummy': [34,45,65]
}
dict_df = pd.DataFrame(my_dict)
dict_df
# Out:
#      Name  Ago  dummy
# 0   nafiz   23     34
# 1  mahmud   34     45
# 2  shawon   45     65

# %%
my_dict = [
    {'Name': 'nafiz', 'age': 34, 'blood': 'o'},
    {'Name': 'mahmud', 'age': 44, 'blood': 'b'},
    {'Name': 'shawon', 'age': 54, 'blood': 'o-'}
    
]
dict_df = pd.DataFrame(my_dict)
dict_df
# Out:
#      Name  age blood
# 0   nafiz   34     o
# 1  mahmud   44     b
# 2  shawon   54    o-

# %%
print(type(dict_df['Name']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 0               1   14    male      public    post graduate          3.1
# 1               2   18  female      public         graduate          3.7
# 2               3   17  female     private    post graduate          7.9
# 3               4   16   other      public      high school          1.1
# 4               5   16  female      public      high school          1.3
# ...           ...  ...     ...         ...              ...          ...
# 24995       12047   17  female      public              phd          1.8
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# ...

# %%
df['school_type']
# Out:
# 0         public
# 1         public
# 2        private
# 3         public
# 4         public
#           ...
# 24995     public
# 24996    private
# 24997    private
# 24998    private
# 24999     public
# Name: school_type, Length: 25000, dtype: object

# %%
type(df['school_type'])
# Out:
# pandas.core.series.Series

# %%
df.loc[1]
# Out:
# student_id                      2
# age                            18
# gender                     female
# school_type                public
# parent_education         graduate
# study_hours                   3.7
# attendance_percentage        87.8
# internet_access               yes
# travel_time               >60 min
# extra_activities               no
# study_method             textbook
# math_score                   57.6
# science_score                68.8
# english_score                64.8
# overall_score                61.3
# final_grade                     d
# Name: 1, dtype: object

# %%
df
# Out:
#        student_id  age  gender school_type parent_education  study_hours  \
# 0               1   14    male      public    post graduate          3.1
# 1               2   18  female      public         graduate          3.7
# 2               3   17  female     private    post graduate          7.9
# 3               4   16   other      public      high school          1.1
# 4               5   16  female      public      high school          1.3
# ...           ...  ...     ...         ...              ...          ...
# 24995       12047   17  female      public              phd          1.8
# 24996        1102   16  female     private          diploma          2.7
# 24997        4422   19   other     private    post graduate          1.0
# 24998        7858   14    male     private          diploma          1.0
# 24999       11621   18   other      public        no formal          0.7
#
#        attendance_percentage internet_access travel_time extra_activities  \
# ...

# %%
type(df.loc[0])
# Out:
# pandas.core.series.Series
